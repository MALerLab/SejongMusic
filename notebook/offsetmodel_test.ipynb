# %%
# %cd ..
# %load_ext autoreload
# %autoreload 2
# Out:
# /home/teo/userdata/SejongMusic

# %%
import torch
from pathlib import Path
from omegaconf import OmegaConf

from sejong_music.jg_code import JeongganDataset, JeongganTokenizer
from sejong_music.model_zoo import JeongganTransSeq2seq
from sejong_music.inference import JGInferencer
from sejong_music.jg_to_staff_converter import JGToStaffConverter, BeatToGenConverter

checkpoint_dir = Path('wandb/run-20240410_181816-zoguj9tp/files/checkpoints')
config_path = checkpoint_dir / 'config.yaml'
vocab_path = checkpoint_dir / 'tokenizer_vocab.json'
model_path = checkpoint_dir / 'inst_0/iter17400_model.pt'

config = OmegaConf.load(config_path)
dataset = JeongganDataset(is_valid=True, use_offset=True)
tokenizer = JeongganTokenizer(None, None, json_fn=vocab_path)
dataset.tokenizer = tokenizer
model = JeongganTransSeq2seq(tokenizer, config.model)
inferencer = JGInferencer(model, is_condition_shifted=True, is_orch=True, top_p=0.7, temperature=0.9)
decoder = JGToStaffConverter()

state_dict = torch.load(model_path, map_location='cpu')
model.load_state_dict(state_dict)
model.cuda()
model.eval()
None

# %%
beat_dataset = JeongganDataset(is_valid=True, use_offset=True)
gen_dataset = JeongganDataset(is_valid=True, use_offset=False)

beat_dataset[0]
# Out:
# (tensor([[  1,   1,   1,   1, 112],
#          [  5, 118, 132, 152, 113],
#          [ 35, 120, 132, 152, 113],
#          ...,
#          [  3, 120, 146, 155, 116],
#          [  4, 118, 147, 155, 116],
#          [  2,   2,   2,   2, 112]]),
#  tensor([[  1, 118, 132, 152, 112],
#          [  5, 120, 132, 152, 112],
#          [ 35, 120, 132, 152, 112],
#          ...,
#          [ 11, 126, 147, 155, 112],
#          [ 74, 126, 147, 155, 112],
#          [  4, 119, 132, 156, 112]]),
#  tensor([  5,  35,  61,   3,   5,  34,  82,   3,  11,  85,   3,   5,  30,   3,
#           11, 100,   4,   5,  35,  61,   3,   5,  34,  82,  11,  83,   3,   5,
#           38,  11,  34,   3,   5,  39,  61,   3,   6,  83,  11,  38,   3,   5,
#           34,  69,  11,  83,   3,   5,  38,   7, 100,  11,  38,  95,   3,   3,
#            3,   3,  11,  35,   3,   5,  34,  69,   7,  38,   3,  11,  34,  69,
#            3,   5,  39,  61,   3,   5,  39,  84,  11,  38,   3,   5,  34,  69,
#            6,  38,  11,  42,  77,   4,   5,  38,   3,  11,  85,   3,   5,  34,
#           69,  11, 100,   3,   9,  38,   6,  81,  11,  42,  14,  67,   3,   5,
#           43,  11,  83,   3,   5,  39,  69,   9,  38,   7,  42,  77,  69,   3,
#            5,  38,   3,   5,  34,  69,  11,  35,  84,   3,   5,  30,   3,   5,
#           30,  82,  11,  83,   3,   5,  34,  11,  83,   3,   5,  38,   3,  14,
#           83,   3,   5,  34,  69,  11,  35,  84,   3,   5,  30,  11,  83,   3,
#            5,  34,   9,  35,  14,  30,  69,   4,   5,  34,  11,  83,   3,   5,
#           38,  11,  85,   3,   5,  34,  69,  11, 100,   3,   5,  39,  61,   3,
#           11,  83,   3,   5,  38,   3,   5,  34,  69,   9,  38,  14,  83,   3,
#            5,  34,  69,  11,  35,  84,   3,   5,  30,   3,   5,  30,  84,  11,
#           83,   3,   5,  34,   6,  83,  11,  38,   3,   5,  34,  68,   3,   3,
#            3,  11,  81,   3,   5,  67,   6,  81,  11,  74,   4,   2]))

# %%
sample, tgt, shifted_tgt = dataset[10]
src, output, (attn, output_tensor, _) = inferencer.inference(sample, 'daegeum')

shifted_tgt = inferencer.beat2gen(tokenizer.decode(shifted_tgt))
shifted_tgt = [x for x in shifted_tgt if x != '']
out_decoded = [x[0] for x in output]
src_gen = inferencer.beat2gen([x[0] for x in src])

# %%
sum([1 for x in out_decoded if x in ('|', '\n')]), sum([1 for x in shifted_tgt if x in ('|', '\n')])
# Out:
# (64, 64)

# %%
from sejong_music.eval_metrics import per_jg_note_acc, onset_f1
target_part_idx = 'daegeum'

jg_note_acc = per_jg_note_acc(out_decoded, shifted_tgt, inst=target_part_idx, tokenizer=inferencer.tokenizer)
f1, prec, recall = onset_f1(out_decoded, shifted_tgt, inst=target_part_idx, tokenizer=inferencer.tokenizer)

jg_note_acc, f1
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[17], line 4
#       1 from sejong_music.eval_metrics import per_jg_note_acc, onset_f1
#       2 target_part_idx = 'daegeum'
# ----> 4 jg_note_acc = per_jg_note_acc(out_decoded, shifted_tgt, inst=target_part_idx, tokenizer=inferencer.tokenizer)
#       5 f1, prec, recall = onset_f1(out_decoded, shifted_tgt, inst=target_part_idx, tokenizer=inferencer.tokenizer)
#       7 jg_note_acc, f1
#
# File ~/userdata/SejongMusic/sejong_music/eval_metrics.py:37, in per_jg_note_acc(pred, gt, inst, tokenizer, num_frame_per_jg, strict, pitch_only)
#      31 pred_roll = JeongganPiece.convert_tokens_to_roll(pred,
#      32                                                  inst=inst,
#      33                                                  num_frame_per_jg=num_frame_per_jg)
#      34 gt_roll = JeongganPiece.convert_tokens_to_roll(gt,
#      35                                                inst=inst,
#      36                                                num_frame_per_jg=num_frame_per_jg)
# ---> 37 assert pred_roll.shape == gt_roll.shape, f"Length of pred and gt must be the same. {pred_roll.shape} != {gt_roll.shape}"
#      39 if pitch_only:
#      40   num_total = np.isin(gt_roll[:, 0], PITCH).sum()
#
# AssertionError: Length of pred and gt must be the same. (384, 6) != (366, 6)

# %%
note_dict, stream = decoder.convert_inference_result(output, src, inferencer.tokenizer.decode(shifted_tgt))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 note_dict, stream = decoder.convert_inference_result(output, src, inferencer.tokenizer.decode(shifted_tgt))
#
# File ~/userdata/SejongMusic/sejong_music/jg_code.py:320, in JeongganTokenizer.decode(self, idx)
#     318   idx = idx.tolist()
#     319 if isinstance(idx, list):
# --> 320   return [self.decode(x) for x in idx]
#     321 return self.vocab[idx]
#
# File ~/userdata/SejongMusic/sejong_music/jg_code.py:320, in <listcomp>(.0)
#     318   idx = idx.tolist()
#     319 if isinstance(idx, list):
# --> 320   return [self.decode(x) for x in idx]
#     321 return self.vocab[idx]
#
# File ~/userdata/SejongMusic/sejong_music/jg_code.py:321, in JeongganTokenizer.decode(self, idx)
#     319 if isinstance(idx, list):
#     320   return [self.decode(x) for x in idx]
# --> 321 return self.vocab[idx]
#
# TypeError: list indices must be integers or slices, not str

# %%
from sejong_music.eval_metrics import per_jg_note_acc, onset_f1
target_part_idx = 'daegeum'

jg_note_acc = per_jg_note_acc(out_decoded, shifted_tgt, inst=target_part_idx, tokenizer=inferencer.tokenizer)
f1, prec, recall = onset_f1(out_decoded, shifted_tgt, inst=target_part_idx, tokenizer=inferencer.tokenizer)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[22], line 4
#       1 from sejong_music.eval_metrics import per_jg_note_acc, onset_f1
#       2 target_part_idx = 'daegeum'
# ----> 4 jg_note_acc = per_jg_note_acc(out_decoded, shifted_tgt, inst=target_part_idx, tokenizer=inferencer.tokenizer)
#       5 f1, prec, recall = onset_f1(out_decoded, shifted_tgt, inst=target_part_idx, tokenizer=inferencer.tokenizer)
#
# File ~/userdata/SejongMusic/sejong_music/eval_metrics.py:34, in per_jg_note_acc(pred, gt, inst, tokenizer, num_frame_per_jg, strict, pitch_only)
#      29   gt = tokenizer.decode(gt)
#      31 pred_roll = JeongganPiece.convert_tokens_to_roll(pred,
#      32                                                  inst=inst,
#      33                                                  num_frame_per_jg=num_frame_per_jg)
# ---> 34 gt_roll = JeongganPiece.convert_tokens_to_roll(gt,
#      35                                                inst=inst,
#      36                                                num_frame_per_jg=num_frame_per_jg)
#      37 assert pred_roll.shape == gt_roll.shape, f"Length of pred and gt must be the same. {pred_roll.shape} != {gt_roll.shape}"
#      39 if pitch_only:
#
# File ~/userdata/SejongMusic/sejong_music/jg_code.py:144, in JeongganPiece.convert_tokens_to_roll(tokens, inst, num_frame_per_jg, num_features)
#     142 start_frame = round((jg_offset + beat_offset) * num_frame_per_jg)
#     143 end_frame = max(round((jg_offset + beat_offset + duration) * num_frame_per_jg), start_frame+1)
# --> 144 outputs[start_frame, 0] = note.pitch
#     145 outputs[start_frame+1:end_frame, 0] = '-'
#     146 if note.ornaments:
#
# IndexError: index 360 is out of bounds for axis 0 with size 360

# %%
inferencer.beat2gen(tokenizer.decode(shifted_tgt)).split(' ')
# Out:
# [':0',
#  '태',
#  '나니로',
#  '|',
#  ':2',
#  '황',
#  '니나',
#  ':8',
#  '니나*',
#  '|',
#  ':2',
#  '중',
#  ':8',
#  '황',
#  '|',
#  ':0',
#  '임',
#  '나니로',
#  '|',
#  ':6',
#  '니나*',
#  ':8',
#  '중',
#  '|',
#  ':2',
#  '황',
#  '노니로',
#  ':8',
#  '니나*',
#  '|',
#  ':2',
#  '중',
#  ':5',
#  '쉼표',
#  ':8',
#  '중',
#  '미는표',
#  '|',
#  '',
#  '|',
#  '',
#  '|',
#  '',
#  '|',
#  ':8',
#  '태',
#  '|',
#  ':2',
#  '황',
#  '노니로',
#  ':5',
#  '중',
#  '|',
#  ':8',
#  '황',
#  '노니로',
#  '|',
#  ':0',
#  '임',
#  '나니로',
#  '|',
#  ':2',
#  '임',
#  '니레',
#  ':8',
#  '중',
#  '|',
#  ':2',
#  '황',
#  '노니로',
#  ':6',
#  '중',
#  ':8',
#  '무',
#  '느니-르',
#  '\n',
#  ':0',
#  '중',
#  '|',
#  ':8',
#  '니레나',
#  '|',
#  ':2',
#  '황',
#  '노니로',
#  ':8',
#  '쉼표',
#  '|',
#  ':3',
#  '중',
#  ':6',
#  '니',
#  ':7',
#  '무',
#  ':9',
#  '노',
#  '|',
#  ':2',
#  '청황',
#  ':8',
#  '니나*',
#  '|',
#  ':1',
#  '임',
#  '노니로',
#  ':3',
#  '중',
#  ':5',
#  '무',
#  '느니-르',
#  '노니로',
#  '|',
#  ':0',
#  '중',
#  '|',
#  ':2',
#  '황',
#  '노니로',
#  ':8',
#  '태',
#  '니레',
#  '|',
#  ':0',
#  '배임',
#  '|',
#  ':2',
#  '배임',
#  '니나',
#  ':8',
#  '니나*',
#  '|',
#  ':2',
#  '황',
#  ':8',
#  '니나*',
#  '|',
#  ':0',
#  '중',
#  '|',
#  ':9',
#  '니나*',
#  '|',
#  ':2',
#  '황',
#  '노니로',
#  ':8',
#  '태',
#  '니레',
#  '|',
#  ':2',
#  '배임',
#  ':8',
#  '니나*',
#  '|',
#  ':1',
#  '황',
#  ':3',
#  '태',
#  ':9',
#  '배임',
#  '노니로',
#  '\n',
#  ':2',
#  '황',
#  ':8',
#  '니나*',
#  '|',
#  ':2',
#  '중',
#  ':8',
#  '니레나',
#  '|',
#  ':2',
#  '황',
#  '노니로',
#  ':8',
#  '쉼표',
#  '|',
#  ':0',
#  '임',
#  '나니로',
#  '|',
#  ':8',
#  '니나*',
#  '|',
#  ':0',
#  '중',
#  '|',
#  ':1',
#  '황',
#  '노니로',
#  ':3',
#  '중',
#  ':9',
#  '니나*',
#  '|',
#  ':2',
#  '황',
#  '노니로',
#  ':8',
#  '태',
#  '니레',
#  '|',
#  ':0',
#  '배임',
#  '|',
#  ':2',
#  '배임',
#  '니레',
#  ':8',
#  '니나*',
#  '|',
#  ':2',
#  '황',
#  ':6',
#  '니나*',
#  ':8',
#  '중',
#  '|',
#  ':0',
#  '황',
#  '노네',
#  '|',
#  '',
#  '|',
#  '',
#  '|',
#  ':8',
#  '니',
#  '|',
#  ':2',
#  '노',
#  ':6',
#  '니',
#  ':8',
#  '느나',
#  '\n',
#  ':0',
#  '임',
#  '니나',
#  '|',
#  ':6',
#  '노',
#  ':8',
#  '무',
#  '느니-르',
#  '|',
#  ':0',
#  '중',
#  '|',
#  ':1',
#  '황',
#  '노니로',
#  ':3',
#  '중',
#  ':9',
#  '니나*',
#  '|',
#  ':2',
#  '황',
#  '노니로',
#  ':8',
#  '태',
#  '니레',
#  '|',
#  ':0',
#  '배임',
#  '|',
#  ':2',
#  '배임',
#  '니나',
#  ':8',
#  '니나*',
#  '|',
#  ':2',
#  '황',
#  ':8',
#  '쉼표',
#  '|',
#  ':2',
#  '니나*',
#  ':5',
#  '중',
#  '|',
#  ':2',
#  '황',
#  '노니로',
#  ':8',
#  '니나*',
#  '|',
#  ':2',
#  '중',
#  ':8',
#  '느니',
#  '|',
#  ':2',
#  '임',
#  ':8',
#  '니나*',
#  '|',
#  ':0',
#  '중']

# %%
out_decoded
# Out:
# [[':0', 'prevbeat:0', 'jg:0', 'gak:0', 'daegeum'],
#  ['태', 'prevbeat:0', 'jg:0', 'gak:0', 'daegeum'],
#  ['나니로', 'prevbeat:0', 'jg:0', 'gak:0', 'daegeum'],
#  ['|', 'prev|', 'jg:1', 'gak:0', 'daegeum'],
#  [':2', 'prevbeat:0', 'jg:1', 'gak:0', 'daegeum'],
#  ['황', 'prevbeat:0', 'jg:1', 'gak:0', 'daegeum'],
#  ['니나', 'prevbeat:0', 'jg:1', 'gak:0', 'daegeum'],
#  [':8', 'prevbeat:2/3', 'jg:1', 'gak:0', 'daegeum'],
#  ['니나*', 'prevbeat:2/3', 'jg:1', 'gak:0', 'daegeum'],
#  ['|', 'prev|', 'jg:2', 'gak:0', 'daegeum'],
#  [':2', 'prevbeat:0', 'jg:2', 'gak:0', 'daegeum'],
#  ['중', 'prevbeat:0', 'jg:2', 'gak:0', 'daegeum'],
#  [':9', 'prevbeat:5/6', 'jg:2', 'gak:0', 'daegeum'],
#  ['황', 'prevbeat:5/6', 'jg:2', 'gak:0', 'daegeum'],
#  ['|', 'prev|', 'jg:3', 'gak:0', 'daegeum'],
#  [':0', 'prevbeat:0', 'jg:3', 'gak:0', 'daegeum'],
#  ['임', 'prevbeat:0', 'jg:3', 'gak:0', 'daegeum'],
#  ['나니로', 'prevbeat:0', 'jg:3', 'gak:0', 'daegeum'],
#  ['|', 'prev|', 'jg:4', 'gak:0', 'daegeum'],
#  [':6', 'prevbeat:1/2', 'jg:4', 'gak:0', 'daegeum'],
#  ['니나*', 'prevbeat:1/2', 'jg:4', 'gak:0', 'daegeum'],
#  [':8', 'prevbeat:2/3', 'jg:4', 'gak:0', 'daegeum'],
#  ['중', 'prevbeat:2/3', 'jg:4', 'gak:0', 'daegeum'],
#  ['|', 'prev|', 'jg:5', 'gak:0', 'daegeum'],
#  [':2', 'prevbeat:0', 'jg:5', 'gak:0', 'daegeum'],
#  ['황', 'prevbeat:0', 'jg:5', 'gak:0', 'daegeum'],
#  ['노니로', 'prevbeat:0', 'jg:5', 'gak:0', 'daegeum'],
#  [':8', 'prevbeat:2/3', 'jg:5', 'gak:0', 'daegeum'],
#  ['니나*', 'prevbeat:2/3', 'jg:5', 'gak:0', 'daegeum'],
#  ['|', 'prev|', 'jg:6', 'gak:0', 'daegeum'],
#  [':2', 'prevbeat:0', 'jg:6', 'gak:0', 'daegeum'],
#  ['중', 'prevbeat:0', 'jg:6', 'gak:0', 'daegeum'],
#  [':5', 'prevbeat:1/3', 'jg:6', 'gak:0', 'daegeum'],
#  ['쉼표', 'prevbeat:1/3', 'jg:6', 'gak:0', 'daegeum'],
#  [':8', 'prevbeat:2/3', 'jg:6', 'gak:0', 'daegeum'],
#  ['중', 'prevbeat:2/3', 'jg:6', 'gak:0', 'daegeum'],
#  ['|', 'prev|', 'jg:7', 'gak:0', 'daegeum'],
#  ['|', 'prev|', 'jg:8', 'gak:0', 'daegeum'],
#  ['|', 'prev|', 'jg:9', 'gak:0', 'daegeum'],
#  ['|', 'prev|', 'jg:10', 'gak:0', 'daegeum'],
#  [':8', 'prevbeat:2/3', 'jg:10', 'gak:0', 'daegeum'],
#  ['태', 'prevbeat:2/3', 'jg:10', 'gak:0', 'daegeum'],
#  ['|', 'prev|', 'jg:11', 'gak:0', 'daegeum'],
#  [':1', 'prevbeat:0', 'jg:11', 'gak:0', 'daegeum'],
#  ['황', 'prevbeat:0', 'jg:11', 'gak:0', 'daegeum'],
#  ['노니로', 'prevbeat:0', 'jg:11', 'gak:0', 'daegeum'],
#  [':3', 'prevbeat:1/6', 'jg:11', 'gak:0', 'daegeum'],
#  ['중', 'prevbeat:1/6', 'jg:11', 'gak:0', 'daegeum'],
#  ['|', 'prev|', 'jg:12', 'gak:0', 'daegeum'],
#  [':8', 'prevbeat:2/3', 'jg:12', 'gak:0', 'daegeum'],
#  ['황', 'prevbeat:2/3', 'jg:12', 'gak:0', 'daegeum'],
#  ['노니로', 'prevbeat:2/3', 'jg:12', 'gak:0', 'daegeum'],
#  ['|', 'prev|', 'jg:13', 'gak:0', 'daegeum'],
#  [':0', 'prevbeat:0', 'jg:13', 'gak:0', 'daegeum'],
#  ['임', 'prevbeat:0', 'jg:13', 'gak:0', 'daegeum'],
#  ['나니로', 'prevbeat:0', 'jg:13', 'gak:0', 'daegeum'],
#  ['|', 'prev|', 'jg:14', 'gak:0', 'daegeum'],
#  [':2', 'prevbeat:0', 'jg:14', 'gak:0', 'daegeum'],
#  ['임', 'prevbeat:0', 'jg:14', 'gak:0', 'daegeum'],
#  ['니레', 'prevbeat:0', 'jg:14', 'gak:0', 'daegeum'],
#  [':8', 'prevbeat:2/3', 'jg:14', 'gak:0', 'daegeum'],
#  ['중', 'prevbeat:2/3', 'jg:14', 'gak:0', 'daegeum'],
#  ['|', 'prev|', 'jg:15', 'gak:0', 'daegeum'],
#  [':2', 'prevbeat:0', 'jg:15', 'gak:0', 'daegeum'],
#  ['황', 'prevbeat:0', 'jg:15', 'gak:0', 'daegeum'],
#  ['노니로', 'prevbeat:0', 'jg:15', 'gak:0', 'daegeum'],
#  [':6', 'prevbeat:1/2', 'jg:15', 'gak:0', 'daegeum'],
#  ['중', 'prevbeat:1/2', 'jg:15', 'gak:0', 'daegeum'],
#  [':8', 'prevbeat:2/3', 'jg:15', 'gak:0', 'daegeum'],
#  ['임', 'prevbeat:2/3', 'jg:15', 'gak:0', 'daegeum'],
#  ['나니나', 'prevbeat:2/3', 'jg:15', 'gak:0', 'daegeum'],
#  ['\n', 'prev\n', 'jg:0', 'gak:1', 'daegeum'],
#  [':0', 'prevbeat:0', 'jg:0', 'gak:1', 'daegeum'],
#  ['중', 'prevbeat:0', 'jg:0', 'gak:1', 'daegeum'],
#  ['|', 'prev|', 'jg:1', 'gak:1', 'daegeum'],
#  [':8', 'prevbeat:2/3', 'jg:1', 'gak:1', 'daegeum'],
#  ['니레나', 'prevbeat:2/3', 'jg:1', 'gak:1', 'daegeum'],
#  ['|', 'prev|', 'jg:2', 'gak:1', 'daegeum'],
#  [':2', 'prevbeat:0', 'jg:2', 'gak:1', 'daegeum'],
#  ['황', 'prevbeat:0', 'jg:2', 'gak:1', 'daegeum'],
#  ['노니로', 'prevbeat:0', 'jg:2', 'gak:1', 'daegeum'],
#  [':8', 'prevbeat:2/3', 'jg:2', 'gak:1', 'daegeum'],
#  ['쉼표', 'prevbeat:2/3', 'jg:2', 'gak:1', 'daegeum'],
#  ['|', 'prev|', 'jg:3', 'gak:1', 'daegeum'],
#  [':2', 'prevbeat:0', 'jg:3', 'gak:1', 'daegeum'],
#  ['중', 'prevbeat:0', 'jg:3', 'gak:1', 'daegeum'],
#  [':6', 'prevbeat:1/2', 'jg:3', 'gak:1', 'daegeum'],
#  ['임', 'prevbeat:1/2', 'jg:3', 'gak:1', 'daegeum'],
#  [':7', 'prevbeat:2/3', 'jg:3', 'gak:1', 'daegeum'],
#  ['무', 'prevbeat:2/3', 'jg:3', 'gak:1', 'daegeum'],
#  [':9', 'prevbeat:5/6', 'jg:3', 'gak:1', 'daegeum'],
#  ['임', 'prevbeat:5/6', 'jg:3', 'gak:1', 'daegeum'],
#  ['|', 'prev|', 'jg:4', 'gak:1', 'daegeum'],
#  [':2', 'prevbeat:0', 'jg:4', 'gak:1', 'daegeum'],
#  ['청황', 'prevbeat:0', 'jg:4', 'gak:1', 'daegeum'],
#  [':8', 'prevbeat:2/3', 'jg:4', 'gak:1', 'daegeum'],
#  ['니나*', 'prevbeat:2/3', 'jg:4', 'gak:1', 'daegeum'],
#  ['|', 'prev|', 'jg:5', 'gak:1', 'daegeum'],
#  [':1', 'prevbeat:0', 'jg:5', 'gak:1', 'daegeum'],
#  ['임', 'prevbeat:0', 'jg:5', 'gak:1', 'daegeum'],
#  ['노니로', 'prevbeat:0', 'jg:5', 'gak:1', 'daegeum'],
#  [':3', 'prevbeat:1/6', 'jg:5', 'gak:1', 'daegeum'],
#  ['중', 'prevbeat:1/6', 'jg:5', 'gak:1', 'daegeum'],
#  [':5', 'prevbeat:1/3', 'jg:5', 'gak:1', 'daegeum'],
#  ['무', 'prevbeat:1/3', 'jg:5', 'gak:1', 'daegeum'],
#  ['느니-르', 'prevbeat:1/3', 'jg:5', 'gak:1', 'daegeum'],
#  ['노니로', 'prevbeat:1/3', 'jg:5', 'gak:1', 'daegeum'],
#  ['|', 'prev|', 'jg:6', 'gak:1', 'daegeum'],
#  [':0', 'prevbeat:0', 'jg:6', 'gak:1', 'daegeum'],
#  ['중', 'prevbeat:0', 'jg:6', 'gak:1', 'daegeum'],
#  ['|', 'prev|', 'jg:7', 'gak:1', 'daegeum'],
#  [':2', 'prevbeat:0', 'jg:7', 'gak:1', 'daegeum'],
#  ['황', 'prevbeat:0', 'jg:7', 'gak:1', 'daegeum'],
#  ['노니로', 'prevbeat:0', 'jg:7', 'gak:1', 'daegeum'],
#  [':8', 'prevbeat:2/3', 'jg:7', 'gak:1', 'daegeum'],
#  ['태', 'prevbeat:2/3', 'jg:7', 'gak:1', 'daegeum'],
#  ['니레', 'prevbeat:2/3', 'jg:7', 'gak:1', 'daegeum'],
#  ['|', 'prev|', 'jg:8', 'gak:1', 'daegeum'],
#  [':0', 'prevbeat:0', 'jg:8', 'gak:1', 'daegeum'],
#  ['배임', 'prevbeat:0', 'jg:8', 'gak:1', 'daegeum'],
#  ['|', 'prev|', 'jg:9', 'gak:1', 'daegeum'],
#  [':2', 'prevbeat:0', 'jg:9', 'gak:1', 'daegeum'],
#  ['배임', 'prevbeat:0', 'jg:9', 'gak:1', 'daegeum'],
#  ['니나', 'prevbeat:0', 'jg:9', 'gak:1', 'daegeum'],
#  [':8', 'prevbeat:2/3', 'jg:9', 'gak:1', 'daegeum'],
#  ['니나*', 'prevbeat:2/3', 'jg:9', 'gak:1', 'daegeum'],
#  ['|', 'prev|', 'jg:10', 'gak:1', 'daegeum'],
#  [':2', 'prevbeat:0', 'jg:10', 'gak:1', 'daegeum'],
#  ['황', 'prevbeat:0', 'jg:10', 'gak:1', 'daegeum'],
#  [':8', 'prevbeat:2/3', 'jg:10', 'gak:1', 'daegeum'],
#  ['니나*', 'prevbeat:2/3', 'jg:10', 'gak:1', 'daegeum'],
#  ['|', 'prev|', 'jg:11', 'gak:1', 'daegeum'],
#  [':0', 'prevbeat:0', 'jg:11', 'gak:1', 'daegeum'],
#  ['중', 'prevbeat:0', 'jg:11', 'gak:1', 'daegeum'],
#  ['|', 'prev|', 'jg:12', 'gak:1', 'daegeum'],
#  [':9', 'prevbeat:5/6', 'jg:12', 'gak:1', 'daegeum'],
#  ['니나*', 'prevbeat:5/6', 'jg:12', 'gak:1', 'daegeum'],
#  ['|', 'prev|', 'jg:13', 'gak:1', 'daegeum'],
#  [':2', 'prevbeat:0', 'jg:13', 'gak:1', 'daegeum'],
#  ['황', 'prevbeat:0', 'jg:13', 'gak:1', 'daegeum'],
#  ['노니로', 'prevbeat:0', 'jg:13', 'gak:1', 'daegeum'],
#  [':8', 'prevbeat:2/3', 'jg:13', 'gak:1', 'daegeum'],
#  ['태', 'prevbeat:2/3', 'jg:13', 'gak:1', 'daegeum'],
#  ['니레', 'prevbeat:2/3', 'jg:13', 'gak:1', 'daegeum'],
#  ['|', 'prev|', 'jg:14', 'gak:1', 'daegeum'],
#  [':2', 'prevbeat:0', 'jg:14', 'gak:1', 'daegeum'],
#  ['배임', 'prevbeat:0', 'jg:14', 'gak:1', 'daegeum'],
#  [':8', 'prevbeat:2/3', 'jg:14', 'gak:1', 'daegeum'],
#  ['니나*', 'prevbeat:2/3', 'jg:14', 'gak:1', 'daegeum'],
#  ['|', 'prev|', 'jg:15', 'gak:1', 'daegeum'],
#  [':1', 'prevbeat:0', 'jg:15', 'gak:1', 'daegeum'],
#  ['황', 'prevbeat:0', 'jg:15', 'gak:1', 'daegeum'],
#  [':3', 'prevbeat:1/6', 'jg:15', 'gak:1', 'daegeum'],
#  ['태', 'prevbeat:1/6', 'jg:15', 'gak:1', 'daegeum'],
#  [':9', 'prevbeat:5/6', 'jg:15', 'gak:1', 'daegeum'],
#  ['배임', 'prevbeat:5/6', 'jg:15', 'gak:1', 'daegeum'],
#  ['노니로', 'prevbeat:5/6', 'jg:15', 'gak:1', 'daegeum'],
#  ['\n', 'prev\n', 'jg:0', 'gak:2', 'daegeum'],
#  [':2', 'prevbeat:0', 'jg:0', 'gak:2', 'daegeum'],
#  ['황', 'prevbeat:0', 'jg:0', 'gak:2', 'daegeum'],
#  [':8', 'prevbeat:2/3', 'jg:0', 'gak:2', 'daegeum'],
#  ['니나*', 'prevbeat:2/3', 'jg:0', 'gak:2', 'daegeum'],
#  ['|', 'prev|', 'jg:1', 'gak:2', 'daegeum'],
#  [':2', 'prevbeat:0', 'jg:1', 'gak:2', 'daegeum'],
#  ['중', 'prevbeat:0', 'jg:1', 'gak:2', 'daegeum'],
#  [':8', 'prevbeat:2/3', 'jg:1', 'gak:2', 'daegeum'],
#  ['니레나', 'prevbeat:2/3', 'jg:1', 'gak:2', 'daegeum'],
#  ['|', 'prev|', 'jg:2', 'gak:2', 'daegeum'],
#  [':2', 'prevbeat:0', 'jg:2', 'gak:2', 'daegeum'],
#  ['황', 'prevbeat:0', 'jg:2', 'gak:2', 'daegeum'],
#  ['노니로', 'prevbeat:0', 'jg:2', 'gak:2', 'daegeum'],
#  [':8', 'prevbeat:2/3', 'jg:2', 'gak:2', 'daegeum'],
#  ['쉼표', 'prevbeat:2/3', 'jg:2', 'gak:2', 'daegeum'],
#  ['|', 'prev|', 'jg:3', 'gak:2', 'daegeum'],
#  [':0', 'prevbeat:0', 'jg:3', 'gak:2', 'daegeum'],
#  ['임', 'prevbeat:0', 'jg:3', 'gak:2', 'daegeum'],
#  ['나니로', 'prevbeat:0', 'jg:3', 'gak:2', 'daegeum'],
#  ['|', 'prev|', 'jg:4', 'gak:2', 'daegeum'],
#  [':8', 'prevbeat:2/3', 'jg:4', 'gak:2', 'daegeum'],
#  ['니나*', 'prevbeat:2/3', 'jg:4', 'gak:2', 'daegeum'],
#  ['|', 'prev|', 'jg:5', 'gak:2', 'daegeum'],
#  [':0', 'prevbeat:0', 'jg:5', 'gak:2', 'daegeum'],
#  ['중', 'prevbeat:0', 'jg:5', 'gak:2', 'daegeum'],
#  ['|', 'prev|', 'jg:6', 'gak:2', 'daegeum'],
#  [':1', 'prevbeat:0', 'jg:6', 'gak:2', 'daegeum'],
#  ['황', 'prevbeat:0', 'jg:6', 'gak:2', 'daegeum'],
#  ['노니로', 'prevbeat:0', 'jg:6', 'gak:2', 'daegeum'],
#  [':3', 'prevbeat:1/6', 'jg:6', 'gak:2', 'daegeum'],
#  ['중', 'prevbeat:1/6', 'jg:6', 'gak:2', 'daegeum'],
#  [':9', 'prevbeat:5/6', 'jg:6', 'gak:2', 'daegeum'],
#  ['니나*', 'prevbeat:5/6', 'jg:6', 'gak:2', 'daegeum'],
#  ['|', 'prev|', 'jg:7', 'gak:2', 'daegeum'],
#  [':2', 'prevbeat:0', 'jg:7', 'gak:2', 'daegeum'],
#  ['황', 'prevbeat:0', 'jg:7', 'gak:2', 'daegeum'],
#  ['노니로', 'prevbeat:0', 'jg:7', 'gak:2', 'daegeum'],
#  [':8', 'prevbeat:2/3', 'jg:7', 'gak:2', 'daegeum'],
#  ['태', 'prevbeat:2/3', 'jg:7', 'gak:2', 'daegeum'],
#  ['니레', 'prevbeat:2/3', 'jg:7', 'gak:2', 'daegeum'],
#  ['|', 'prev|', 'jg:8', 'gak:2', 'daegeum'],
#  [':0', 'prevbeat:0', 'jg:8', 'gak:2', 'daegeum'],
#  ['배임', 'prevbeat:0', 'jg:8', 'gak:2', 'daegeum'],
#  ['|', 'prev|', 'jg:9', 'gak:2', 'daegeum'],
#  [':2', 'prevbeat:0', 'jg:9', 'gak:2', 'daegeum'],
#  ['배임', 'prevbeat:0', 'jg:9', 'gak:2', 'daegeum'],
#  ['니나', 'prevbeat:0', 'jg:9', 'gak:2', 'daegeum'],
#  [':8', 'prevbeat:2/3', 'jg:9', 'gak:2', 'daegeum'],
#  ['니나*', 'prevbeat:2/3', 'jg:9', 'gak:2', 'daegeum'],
#  ['|', 'prev|', 'jg:10', 'gak:2', 'daegeum'],
#  [':2', 'prevbeat:0', 'jg:10', 'gak:2', 'daegeum'],
#  ['황', 'prevbeat:0', 'jg:10', 'gak:2', 'daegeum'],
#  [':6', 'prevbeat:1/2', 'jg:10', 'gak:2', 'daegeum'],
#  ['니나*', 'prevbeat:1/2', 'jg:10', 'gak:2', 'daegeum'],
#  [':8', 'prevbeat:2/3', 'jg:10', 'gak:2', 'daegeum'],
#  ['중', 'prevbeat:2/3', 'jg:10', 'gak:2', 'daegeum'],
#  ['|', 'prev|', 'jg:11', 'gak:2', 'daegeum'],
#  [':0', 'prevbeat:0', 'jg:11', 'gak:2', 'daegeum'],
#  ['황', 'prevbeat:0', 'jg:11', 'gak:2', 'daegeum'],
#  ['노네', 'prevbeat:0', 'jg:11', 'gak:2', 'daegeum'],
#  ['|', 'prev|', 'jg:12', 'gak:2', 'daegeum'],
#  ['|', 'prev|', 'jg:13', 'gak:2', 'daegeum'],
#  [':8', 'prevbeat:2/3', 'jg:13', 'gak:2', 'daegeum'],
#  ['니', 'prevbeat:2/3', 'jg:13', 'gak:2', 'daegeum'],
#  ['|', 'prev|', 'jg:14', 'gak:2', 'daegeum'],
#  [':2', 'prevbeat:0', 'jg:14', 'gak:2', 'daegeum'],
#  ['노', 'prevbeat:0', 'jg:14', 'gak:2', 'daegeum'],
#  [':6', 'prevbeat:1/2', 'jg:14', 'gak:2', 'daegeum'],
#  ['니', 'prevbeat:1/2', 'jg:14', 'gak:2', 'daegeum'],
#  [':8', 'prevbeat:2/3', 'jg:14', 'gak:2', 'daegeum'],
#  ['느나', 'prevbeat:2/3', 'jg:14', 'gak:2', 'daegeum'],
#  ['|', 'prev|', 'jg:15', 'gak:2', 'daegeum'],
#  [':0', 'prevbeat:0', 'jg:15', 'gak:2', 'daegeum'],
#  ['쉼표', 'prevbeat:0', 'jg:15', 'gak:2', 'daegeum'],
#  ['\n', 'prev\n', 'jg:0', 'gak:3', 'daegeum'],
#  [':0', 'prevbeat:0', 'jg:0', 'gak:3', 'daegeum'],
#  ['임', 'prevbeat:0', 'jg:0', 'gak:3', 'daegeum'],
#  ['나니로', 'prevbeat:0', 'jg:0', 'gak:3', 'daegeum'],
#  ['|', 'prev|', 'jg:1', 'gak:3', 'daegeum'],
#  ['|', 'prev|', 'jg:2', 'gak:3', 'daegeum'],
#  [':2', 'prevbeat:0', 'jg:2', 'gak:3', 'daegeum'],
#  ['중', 'prevbeat:0', 'jg:2', 'gak:3', 'daegeum'],
#  [':9', 'prevbeat:5/6', 'jg:2', 'gak:3', 'daegeum'],
#  ['황', 'prevbeat:5/6', 'jg:2', 'gak:3', 'daegeum'],
#  ['|', 'prev|', 'jg:3', 'gak:3', 'daegeum'],
#  [':0', 'prevbeat:0', 'jg:3', 'gak:3', 'daegeum'],
#  ['중', 'prevbeat:0', 'jg:3', 'gak:3', 'daegeum'],
#  ['|', 'prev|', 'jg:4', 'gak:3', 'daegeum'],
#  [':2', 'prevbeat:0', 'jg:4', 'gak:3', 'daegeum'],
#  ['황', 'prevbeat:0', 'jg:4', 'gak:3', 'daegeum'],
#  ['노니로', 'prevbeat:0', 'jg:4', 'gak:3', 'daegeum'],
#  [':8', 'prevbeat:2/3', 'jg:4', 'gak:3', 'daegeum'],
#  ['니나*', 'prevbeat:2/3', 'jg:4', 'gak:3', 'daegeum'],
#  ['|', 'prev|', 'jg:5', 'gak:3', 'daegeum'],
#  [':0', 'prevbeat:0', 'jg:5', 'gak:3', 'daegeum'],
#  ['중', 'prevbeat:0', 'jg:5', 'gak:3', 'daegeum'],
#  ['|', 'prev|', 'jg:6', 'gak:3', 'daegeum'],
#  [':2', 'prevbeat:0', 'jg:6', 'gak:3', 'daegeum'],
#  ['황', 'prevbeat:0', 'jg:6', 'gak:3', 'daegeum'],
#  ['노니로', 'prevbeat:0', 'jg:6', 'gak:3', 'daegeum'],
#  [':8', 'prevbeat:2/3', 'jg:6', 'gak:3', 'daegeum'],
#  ['니레나', 'prevbeat:2/3', 'jg:6', 'gak:3', 'daegeum'],
#  ['|', 'prev|', 'jg:7', 'gak:3', 'daegeum'],
#  [':2', 'prevbeat:0', 'jg:7', 'gak:3', 'daegeum'],
#  ['황', 'prevbeat:0', 'jg:7', 'gak:3', 'daegeum'],
#  ['노니로', 'prevbeat:0', 'jg:7', 'gak:3', 'daegeum'],
#  [':8', 'prevbeat:2/3', 'jg:7', 'gak:3', 'daegeum'],
#  ['태', 'prevbeat:2/3', 'jg:7', 'gak:3', 'daegeum'],
#  ['니레', 'prevbeat:2/3', 'jg:7', 'gak:3', 'daegeum'],
#  ['|', 'prev|', 'jg:8', 'gak:3', 'daegeum'],
#  [':0', 'prevbeat:0', 'jg:8', 'gak:3', 'daegeum'],
#  ['중', 'prevbeat:0', 'jg:8', 'gak:3', 'daegeum'],
#  ['|', 'prev|', 'jg:9', 'gak:3', 'daegeum'],
#  [':9', 'prevbeat:5/6', 'jg:9', 'gak:3', 'daegeum'],
#  ['황', 'prevbeat:5/6', 'jg:9', 'gak:3', 'daegeum'],
#  ['|', 'prev|', 'jg:10', 'gak:3', 'daegeum'],
#  [':2', 'prevbeat:0', 'jg:10', 'gak:3', 'daegeum'],
#  ['태', 'prevbeat:0', 'jg:10', 'gak:3', 'daegeum'],
#  [':8', 'prevbeat:2/3', 'jg:10', 'gak:3', 'daegeum'],
#  ['황', 'prevbeat:2/3', 'jg:10', 'gak:3', 'daegeum'],
#  ['|', 'prev|', 'jg:11', 'gak:3', 'daegeum'],
#  [':2', 'prevbeat:0', 'jg:11', 'gak:3', 'daegeum'],
#  ['임', 'prevbeat:0', 'jg:11', 'gak:3', 'daegeum'],
#  ['니레', 'prevbeat:0', 'jg:11', 'gak:3', 'daegeum'],
#  [':8', 'prevbeat:2/3', 'jg:11', 'gak:3', 'daegeum'],
#  ['니나*', 'prevbeat:2/3', 'jg:11', 'gak:3', 'daegeum'],
#  ['|', 'prev|', 'jg:12', 'gak:3', 'daegeum'],
#  [':2', 'prevbeat:0', 'jg:12', 'gak:3', 'daegeum'],
#  ['중', 'prevbeat:0', 'jg:12', 'gak:3', 'daegeum'],
#  [':8', 'prevbeat:2/3', 'jg:12', 'gak:3', 'daegeum'],
#  ['임', 'prevbeat:2/3', 'jg:12', 'gak:3', 'daegeum'],
#  ['니레', 'prevbeat:2/3', 'jg:12', 'gak:3', 'daegeum'],
#  ['\n', 'prev\n', 'jg:0', 'gak:4', 'daegeum']]
